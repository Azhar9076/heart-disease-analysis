# %% [markdown]
# ## Heart Disease Analysis

# %% [markdown]
# ### Questions
# 1. Import The Libraries And Dataset
# 2. Display Top 5 Rows of The Dataset
# 3. Check The Last 5 Rows of The Dataset
# 4. Find Shape of Our Dataset (Number of Rows And Number of Columns)
# 5. Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement
# 6. Check Null Values In The Dataset
# 7. Check For Duplicate Data and Drop Them
# 8. Get Overall Statistics About The Dataset
# 9. Draw Correlation Matrix
# 10. How Many People Have Heart Disease, And How Many Don't Have Heart Disease In This Dataset?
# 11. Find Count of  Male & Female in this Dataset
# 12. Find Gender Distribution According to The Target Variable
# 13. Check Age Distribution In The Dataset
# 14. Check Chest Pain Type
# 15. Show The Chest Pain Distribution As Per Target Variable
# 16. Show Fasting Blood Sugar Distribution According To Target Variable
# 17.  Check Resting Blood Pressure Distribution
# 18. Compare Resting Blood Pressure As Per Sex Column
# 19. Show Distribution of Serum cholesterol
# 20. Plot Continuous Variables

# %%
# 1.Import libraries and Dataset 
import pandas as pd
import numpy as np

# 2. Display Top 5 rows of dataset
df = pd.read_csv('heart.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
# Check The Last 5 Rows of The Dataset
df.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
# 4.Find Shape of Our Dataset (Number of Rows And Number of Columns)
df.shape
# Out:
# (1025, 14)

# %%
#5.Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement
#1.Total Number Rows
df.shape[0]
# Out:
# 1025

# %%
# 2.Total Number of Colums
df.shape[1]
# Out:
# 14

# %%
# Datatypes of Each Column 
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
# Memory Requirement
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
# 6.Check Null Values In The Dataset
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
# 7.Check For Duplicate Data and Drop Them
# Checking Duplicate data 
df[df.duplicated()]
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 15     34    0   1       118   210    0        1      192      0      0.7
# 31     50    0   1       120   244    0        1      162      0      1.1
# 43     46    1   0       120   249    0        0      144      0      0.8
# 55     55    1   0       140   217    0        1      111      1      5.6
# 61     66    0   2       146   278    0        0      152      0      0.0
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 15        2   0     2       1
# ...

# %%
# Droping Duplicate Datas
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# 8.Get Overall Statistics About The Dataset
df.describe()
# Out:
#              age         sex          cp    trestbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    1.397351    0.718543
# ...

# %%
# 9.Draw Correlation Matrix
corr_matrix = df.corr()
corr_matrix
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.094962 -0.063107  0.283121  0.207216  0.119492
# sex      -0.094962  1.000000 -0.051740 -0.057647 -0.195571  0.046022
# cp       -0.063107 -0.051740  1.000000  0.046486 -0.072682  0.096018
# trestbps  0.283121 -0.057647  0.046486  1.000000  0.125256  0.178125
# chol      0.207216 -0.195571 -0.072682  0.125256  1.000000  0.011428
# fbs       0.119492  0.046022  0.096018  0.178125  0.011428  1.000000
# restecg  -0.111590 -0.060351  0.041561 -0.115367 -0.147602 -0.083081
# thalach  -0.395235 -0.046439  0.293367 -0.048023 -0.005308 -0.007169
# exang     0.093216  0.143460 -0.392937  0.068526  0.064099  0.024729
# oldpeak   0.206040  0.098322 -0.146692  0.194600  0.050086  0.004514
# slope    -0.164124 -0.032990  0.116854 -0.122873  0.000417 -0.058654
# ca        0.302261  0.113060 -0.195356  0.099248  0.086878  0.144935
# thal      0.065317  0.211452 -0.160370  0.062870  0.096810 -0.032752
# ...

# %%
# Lets draw using seaborn 
import seaborn as sns
import matplotlib.pyplot as plt

# Plot heatmap
plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix, annot=True, fmt='.2f',cmap='coolwarm', cbar=True)
plt.title('Correlation Matirx', fontsize=14)
plt.tight_layout()
plt.show()

# %%
# 10.How Many People Have Heart Disease, And How Many Don't Have Heart Disease In This Datasetata?
patients = df['target'].value_counts()
patients
# Out:
# target
# 1    164
# 0    138
# Name: count, dtype: int64

# %%
# Count of People who had Heart Disease
cancer_patients = patients[1]
cancer_patients
# Out:
# np.int64(164)

# %%
# Count Of People Dont have Heart Disease
normal_patients = patients[0]
normal_patients
# Out:
# np.int64(138)

# %%
# 11.Find Count of Male & Female in this Dataset
gender = df['sex'].value_counts()
gender
# Out:
# sex
# 1    206
# 0     96
# Name: count, dtype: int64

# %%
# 1.Male Count in dataset
male = gender[1]
male
# Out:
# np.int64(206)

# %%
# 2.Female Count in Dataset
female = gender[0]
female
# Out:
# np.int64(96)

# %%
# 12.Find Gender Distribution According to The Target Variable

Gender_Distribution = pd.crosstab(df['age'], df['target'], margins=True)
Gender_Distribution
# Out:
# target    0    1  All
# age
# 29        0    1    1
# 34        0    2    2
# 35        2    2    4
# 37        0    2    2
# 38        1    1    2
# 39        1    3    4
# 40        2    1    3
# 41        1    9   10
# 42        1    7    8
# 43        3    5    8
# 44        3    8   11
# 45        2    6    8
# 46        3    4    7
# 47        2    3    5
# 48        3    4    7
# 49        2    3    5
# 50        3    4    7
# 51        3    9   12
# 52        4    9   13
# 53        2    6    8
# 54        6   10   16
# 55        5    3    8
# 56        6    5   11
# 57       10    7   17
# 58       12    7   19
# 59        9    5   14
# 60        8    3   11
# 61        7    1    8
# 62        7    4   11
# 63        6    3    9
# 64        4    6   10
# 65        4    4    8
# 66        3    4    7
# 67        6    3    9
# 68        2    2    4
# 69        1    2    3
# 70        3    1    4
# 71        0    3    3
# 74        0    1    1
# 76        0    1    1
# ...

# %%
sns.countplot(x=df['sex'], hue=df['target'])
plt.xticks([1,0],['male', 'female'])
plt.legend(labels=['No_disease', 'disease'])
plt.show()

# %%
# 13. Age Distribution In The Dataset
plt.figure(figsize=(8,6))
sns.histplot(df['age'], kde=True, bins=16)
plt.title('Age Distribution', fontsize=14)
plt.legend(labels=[''])
plt.tight_layout()
plt.show()

# %%
# 14.Check Chest Pain Type
# df['cp'].value_counts()
plt.figure(figsize=(7,5))
sns.countplot(x=df['cp'])
plt.title('Chest Pain Type', fontsize=14)
plt.xticks([0,1,2,3], ["Typical angina", "Atypical angina", "Non-anginal pain", "Asymptomatic"])
plt.show()

# %%
# 15.Show The Chest Pain Distribution As Per Target Variable
plt.figure(figsize=(8,6))
sns.countplot(x=df['cp'], hue=df['target'])
plt.title('Chest Pain Distribution As Per Target Variable', fontsize=14)
plt.xticks([0,1,2,3], ["Typical angina", "Atypical angina", "Non-anginal pain", "Asymptomatic"])
plt.legend(labels=['Male', 'Female'])
plt.show()

# %%
# 16.Show Fasting Blood Sugar Distribution According To Target Variable
# df.columns
plt.figure(figsize=(8,6))
sns.countplot(x=df['fbs'], hue=df['target'])
plt.title('Fasting Blood Sugar Distribution According To Target')
# plt.xticks()
plt.show()

# %%
# 17.Check Resting Blood Pressure Distribution
# df['trestbps'].hist()
plt.figure(figsize=(8,6))
sns.histplot(x='trestbps', data = df)
plt.title('Resting Blood Pressure Distribution')
plt.show()

# %%
# 18.Compare Resting Blood Pressure As Per Sex Column
plt.figure(figsize=(8,6))
sns.boxplot(x='trestbps', hue='target', data)
plt.title('Resting Blood Pressure by Sex')
plt.xlabel('Sex (0 = Female, 1 = Male)')
plt.ylabel('Resting Blood Pressure (mm Hg)')
plt.show()

# %%
# 19.Show Distribution of Serum cholesterol
plt.figure(figsize=(10,6))
sns.histplot(x='chol', kde=True, data=df)
plt.title("Distribution of Serum Cholesterol")
plt.xlabel("Serum Cholesterol (mg/dl)")
plt.ylabel("Count")
plt.show()

# %%
# 20.Plot Continuous Variables
# df.columns
continuous_vars = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']
plt.figure(figsize=(15,10))
for i, col in enumerate(continuous_vars, 1):
    plt.subplot(2,3,i)
    sns.histplot(x=df[col], kde=True, bins=30, color='skyblue')
    plt.title(f'Distribution Of {col}')
plt.tight_layout()
plt.show()
